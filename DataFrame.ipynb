# %%
import pandas as pd

# %%
df_outcomes = pd.read_csv("./merged_data/merged_outcomes.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_outcomes = pd.read_csv("./merged_data/merged_outcomes.csv")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df_stop_and_search = pd.read_csv("./merged_data/merged_stop_and_search.csv")
# Out:
# C:\Users\20242297\AppData\Local\Temp\ipykernel_12284\2585998972.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_stop_and_search = pd.read_csv("./merged_data/merged_stop_and_search.csv")

# %%
df_street = pd.read_csv(
    "./merged_data/merged_street.csv",
    usecols=["source_file", "Crime ID", "LSOA code", "Crime type"],  # since data is huge, only the required ones should be retrieved
    dtype=str
)

# %%
df_street.tail()
# Out:
#                            source_file  \
# 94482066  2026-03-wiltshire-street.csv
# 94482067  2026-03-wiltshire-street.csv
# 94482068  2026-03-wiltshire-street.csv
# 94482069  2026-03-wiltshire-street.csv
# 94482070  2026-03-wiltshire-street.csv
#
#                                                    Crime ID  LSOA code  \
# 94482066  fc3d7314130de9300bafc78922607eebf20427535d0af9...  E01034558
# 94482067  1def15185912271876d00126c1e2123957cac2fbbf7b29...  E01034558
# 94482068  1856ca82c342e60c423f8614b2e8e941a52eaf1d2bd8d2...  E01034558
# 94482069  0d5c19c0980cc4ec25c8bec736dcde415897cadcb60b52...  E01034558
# 94482070  9688e4e9ebd1b3448852234e17b1fcc429b22724e15625...  E01030966
#
#                             Crime type
# 94482066                  Public order
# 94482067                  Public order
# 94482068                  Public order
# 94482069  Violence and sexual offences
# 94482070                   Other crime
